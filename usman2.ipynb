# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
info = pd.read_csv("E:players_20.csv")

# %%
analyzing= info[["short_name","nationality", "wage_eur", "defending","club"]]

# %%
tott=analyzing[analyzing["club"]=="Tottenham Hotspur"]
tott
# Out:
#              short_name          nationality  wage_eur  defending  \
# 12              H. Kane              England    220000       47.0
# 27           C. Eriksen              Denmark    205000       53.0
# 32            H. Lloris               France    150000        NaN
# 43               H. Son       Korea Republic    185000       42.0
# 47        J. Vertonghen              Belgium    155000       87.0
# 50      T. Alderweireld              Belgium    155000       88.0
# 113             D. Alli              England    115000       71.0
# 159         G. Lo Celso            Argentina    105000       65.0
# 177          D. Sánchez             Colombia     93000       83.0
# 197         Lucas Moura               Brazil    130000       42.0
# 331         T. Ndombele               France     87000       70.0
# 389          M. Sissoko               France    105000       79.0
# 420            H. Winks              England     82000       71.0
# ...
